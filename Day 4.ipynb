# %% [markdown]
# <h1> Day 4 <h1>

# %%
#Importing necessary libreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df=pd.read_csv('Student_Behaviour.csv')
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
#no. of row and columns
df.shape
# Out:
# (235, 19)

# %%
#info of the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    str
#  1   Gender                                                  235 non-null    str
#  2   Department                                              235 non-null    str
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
# stat of the dataset
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
#missing value
df.isnull().sum()
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# Height(CM)                                                0
# Weight(KG)                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# ...

# %%
# no of columns
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
# how to access the col
df.Gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 230      Male
# 231      Male
# 232    Female
# 233    Female
# 234    Female
# Name: Gender, Length: 235, dtype: str

# %%
df['salary expectation']
# Out:
# 0        40000
# 1        15000
# 2        13000
# 3      1500000
# 4        50000
#         ...
# 230       7000
# 231      25000
# 232      20000
# 233      20000
# 234         10
# Name: salary expectation, Length: 235, dtype: int64

# %%
# row
df.loc[1:10]
# Out:
#    Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 1                    No  Female        BCA        90.0        40.0       70.0
# 2                   Yes    Male        BCA       159.0        78.0       69.5
# 3                   Yes  Female        BCA       147.0        20.0       70.0
# 4                    No    Male        BCA       170.0        54.0       40.0
# 5                   Yes  Female        BCA       139.0        33.0       90.0
# 6                   Yes    Male        BCA       165.0        50.0       70.0
# 7                    No    Male        BCA       152.0        43.0       61.6
# 8                    No    Male        BCA       190.0        85.0       88.2
# 9                    No    Male        BCA       150.0        84.0       60.0
# 10                   No    Male        BCA        99.0        50.0       75.0
#
#     12th Mark  college mark        hobbies daily studing time  \
# ...

# %%
# integer loc(iloc) -rows as well as col
df.iloc[3:6,3:5]
# Out:
#    Height(CM)  Weight(KG)
# 3       147.0        20.0
# 4       170.0        54.0
# 5       139.0        33.0

# %%
df1=df.rename(columns={'Certification Course':'Certification_Course','Stress Level ':'Stress Level'})

# %%
df1.columns
# Out:
# Index(['Certification_Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
df1.rename(columns={'college mark':'college_marks'},inplace=True)
df1.columns
# Out:
# Index(['Certification_Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college_marks', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
#unique value in each col
#gender
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      156
# Female     79
# Name: count, dtype: int64

# %%
# a simple visualization of the gender col
df['Gender'].value_counts().plot(kind='bar')
plt.title('gender')
# Out:
# Text(0.5, 1.0, 'gender')

# %%
df['Financial Status'].value_counts().plot(kind='pie',autopct='1.2f%%')
plt.title('pie chat based on financial')
plt.show()

# %%
#univariate analysis 
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
#bi variate analysis :2 variables
sns.barplot(data=df,x='10th Mark',y='12th Mark')
plt.title('bi variate analysis using bar plot')
plt.show()

# %%
sns.scatterplot(data=df, x='Height(CM)',y='Weight(KG)')
plt.title('scatterplot')
plt.show()

# %%
#heu means comparing
sns.countplot(data=df,x='Stress Level ',hue='Department')
plt.title('countplot')
plt.show()

# %%
# multi variable
num_cols=df.select_dtypes(include='number')
num_cols
# Out:
#      Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  \
# 0         100.0        58.0       79.0       65.0          80.0
# 1          90.0        40.0       70.0       80.0          70.0
# 2         159.0        78.0       69.5       61.0          55.0
# 3         147.0        20.0       70.0       59.0          58.0
# 4         170.0        54.0       40.0       65.0          30.0
# ..          ...         ...        ...        ...           ...
# 230       170.0        76.0       72.0       67.0          65.0
# 231       172.0        52.0       72.0       70.0          76.0
# 232       139.0        33.0       90.0       75.0          70.0
# 233       153.0        58.0       85.0       74.0          75.0
# 234       155.0        39.0       45.0       45.0          50.0
#
#      salary expectation
# 0                 40000
# 1                 15000
# 2                 13000
# 3               1500000
# 4                 50000
# ..                  ...
# ...

# %%
cm=num_cols.corr()
cm
# Out:
#                     Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# Height(CM)            1.000000    0.275948   0.019896  -0.120672
# Weight(KG)            0.275948    1.000000   0.062394  -0.019208
# 10th Mark             0.019896    0.062394   1.000000   0.473618
# 12th Mark            -0.120672   -0.019208   0.473618   1.000000
# college mark         -0.018535   -0.014901   0.466234   0.425123
# salary expectation   -0.010708   -0.087787  -0.055694  -0.085610
#
#                     college mark  salary expectation
# Height(CM)             -0.018535           -0.010708
# Weight(KG)             -0.014901           -0.087787
# 10th Mark               0.466234           -0.055694
# 12th Mark               0.425123           -0.085610
# college mark            1.000000           -0.103034
# salary expectation     -0.103034            1.000000

# %%
sns.heatmap(cm,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#pairplot
sns.pairplot(data=df)

# %%
#filtering
df[df['Department']=='BCA']
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 0                     No    Male        BCA       100.0        58.0
# 1                     No  Female        BCA        90.0        40.0
# 2                    Yes    Male        BCA       159.0        78.0
# 3                    Yes  Female        BCA       147.0        20.0
# 4                     No    Male        BCA       170.0        54.0
# ..                   ...     ...        ...         ...         ...
# 154                  Yes  Female        BCA       156.0        50.0
# 155                  Yes  Female        BCA       160.0        50.0
# 156                  Yes    Male        BCA       175.0        68.9
# 157                  Yes  Female        BCA       155.0        50.0
# 232                  Yes  Female        BCA       139.0        33.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 0         79.0       65.0          80.0    Video Games      0 - 30 minute
# ...

# %%
#filtering
df[df['Department']=='BCA'].shape[0]
# Out:
# 132

# %%
df[(df['Department']=='BCA') & (df['Gender']=='Female')]
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 1                     No  Female        BCA        90.0        40.0
# 3                    Yes  Female        BCA       147.0        20.0
# 5                    Yes  Female        BCA       139.0        33.0
# 11                    No  Female        BCA       152.0        51.0
# 12                   Yes  Female        BCA       158.0        64.0
# 19                   Yes  Female        BCA       109.0        42.0
# 22                    No  Female        BCA       142.0        42.0
# 28                    No  Female        BCA       145.0        39.0
# 29                    No  Female        BCA        99.0        40.0
# 36                    No  Female        BCA       155.0        48.0
# 37                    No  Female        BCA       150.0        45.0
# 40                    No  Female        BCA       175.0        43.0
# 41                    No  Female        BCA        98.0        35.0
# ...

# %%
df[(df['Department']=='BCA') & (df['Gender']=='Male')]
# Out:
#     Certification Course Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                     No   Male        BCA       100.0        58.0       79.0
# 2                    Yes   Male        BCA       159.0        78.0       69.5
# 4                     No   Male        BCA       170.0        54.0       40.0
# 6                    Yes   Male        BCA       165.0        50.0       70.0
# 7                     No   Male        BCA       152.0        43.0       61.6
# ..                   ...    ...        ...         ...         ...        ...
# 146                   No   Male        BCA       165.0        45.0       50.0
# 150                  Yes   Male        BCA       175.0        70.0       90.2
# 151                   No   Male        BCA       175.0        76.0       61.8
# 152                   No   Male        BCA       160.0        70.0       80.0
# 156                  Yes   Male        BCA       175.0        68.9       71.0
#
# ...

# %%
df[(df['Department']=='B.com ISM') & (df['Gender']=='Female')].shape[0]
# Out:
# 6

# %%
df[(df['Department']=='B.com ISM') & (df['Gender']=='Male')].shape[0]
# Out:
# 22

# %%
df[df['Stress Level ']=='Bad'].shape[0]
# Out:
# 68

# %%
df[(df['Department']=='BCA') & (df['Stress Level ']=='fabulous')].shape[0]
# Out:
# 3

# %%
df['prefer to study in'].unique()
# Out:
# <StringArray>
# ['Morning', 'Anytime', 'Night']
# Length: 3, dtype: str

# %%
df['prefer to study in'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
df['prefer to study in'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='prefer to study in'>

# %%
sns.countplot(data=df,x=df['prefer to study in'],hue='Department')
plt.title('countplot')
plt.show()

# %% [markdown]
# # Mechine learning  -Supervised learning

# %%
# import necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
# load the dataset
hr=pd.read_csv(r"C:\Users\theja\Downloads\framingham.csv\Lab 21 House_Rent_Dataset.csv")
hr.head(3)
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner

# %%
hr.shape
# Out:
# (4746, 12)

# %%
hr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   str
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
# dtypes: int64(4), str(8)
# memory usage: 445.1 KB

# %%
hr.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
hr.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='str')

# %%
hr['Furnishing Status'].unique()
# Out:
# <StringArray>
# ['Unfurnished', 'Semi-Furnished', 'Furnished']
# Length: 3, dtype: str

# %%
hr['Tenant Preferred'].unique()
# Out:
# <StringArray>
# ['Bachelors/Family', 'Bachelors', 'Family']
# Length: 3, dtype: str

# %%
plt.figure(figsize=(11,12))
for i,col in enumerate(["Area Type","City","Furnishing Status","Tenant Preferred","Point of Contact"]):
    plt.subplot(4,2,i+1)
    sns.countplot(data=hr,x=col)
